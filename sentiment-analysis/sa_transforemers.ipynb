# %% [markdown]
# <a href="https://colab.research.google.com/github/caprolaliac/MLPrac/blob/main/sentiment-analysis/sa_transforemers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch numpy pandas -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 42.7 MB/s eta 0:00:00

# %%
import torch
import numpy as np
import pandas as pd
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

# %%
df=pd.read_csv('/content/drive/MyDrive/The Acolyte-reviews.csv')
df.head()
# Out:
#                                         Review Title Review Date  \
# 0               Painful - how can it get this bad?\n  10-06-2024
# 1        This is laughably bad writing & direction\n  05-06-2024
# 2   What happened to the $180 million it cost to ...  09-06-2024
# 3   Jar Jar Binks was a museum masterpiece next t...  13-06-2024
# 4                                 Complete garbage\n  12-06-2024
#
#                                       Review Content  User Rating
# 0  Take one of the most exciting and expansive fi...          3.0
# 1  Who in the holy hell read these scripts and sa...          3.0
# 2  Then I've seen episode one and two of The Acol...          3.0
# 3  Meesa no lika dis doodoo.I mean seriously what...          1.0
# 4  I tried to give this series a chance but after...          1.0

# %%
df["review"] = df["Review Title"] + " " + df["Review Content"]

# %%
df.drop(["Review Title", "Review Content"], axis=1, inplace=True)

# %%
df.rename(columns={'review': 'Review'}, inplace=True)

# %%
df
# Out:
#      Review Date  User Rating  \
# 0     10-06-2024          3.0
# 1     05-06-2024          3.0
# 2     09-06-2024          3.0
# 3     13-06-2024          1.0
# 4     12-06-2024          1.0
# ...          ...          ...
# 1488  26-06-2024         10.0
# 1489  26-06-2024          8.0
# 1490  26-06-2024         10.0
# 1491  26-06-2024          8.0
# 1492  26-06-2024          8.0
#
#                                                  Review
# 0      Painful - how can it get this bad?\n Take one...
# 1      This is laughably bad writing & direction\n W...
# 2      What happened to the $180 million it cost to ...
# 3      Jar Jar Binks was a museum masterpiece next t...
# 4      Complete garbage\n I tried to give this serie...
# ...                                                 ...
# 1488   Watch first - then rate! Best new SW show sin...
# 1489   This is NOT Star Wars because it is set 100 y...
# 1490   It's hard to get into but wow it paid off in ...
# ...

# %%
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

# %%
tokenizer = DistilBertTokenizer.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')
model = DistilBertForSequenceClassification.from_pretrained('distilbert/distilbert-base-uncased-finetuned-sst-2-english')

# %%
nlp=pipeline('sentiment-analysis', model=model, tokenizer=tokenizer)

# %%
text=list(df.Review.values)

# %%
results = nlp(text, truncation=True, padding=True)

# %%
r=pd.DataFrame(results)
r.head()
# Out:
#       label     score
# 0  NEGATIVE  0.994506
# 1  NEGATIVE  0.998167
# 2  NEGATIVE  0.999678
# 3  NEGATIVE  0.999729
# 4  NEGATIVE  0.999627

# %%
r.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1493 entries, 0 to 1492
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1493 non-null   object
#  1   score   1493 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 23.5+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1493 entries, 0 to 1492
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Review Date  1493 non-null   object
#  1   User Rating  1472 non-null   float64
#  2   Review       1493 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 35.1+ KB

# %%
#df = df.join(r)
df.head(10)
# Out:
#   Review Date  User Rating                                             Review  \
# 0  10-06-2024          3.0   Painful - how can it get this bad?\n Take one...
# 1  05-06-2024          3.0   This is laughably bad writing & direction\n W...
# 2  09-06-2024          3.0   What happened to the $180 million it cost to ...
# 3  13-06-2024          1.0   Jar Jar Binks was a museum masterpiece next t...
# 4  12-06-2024          1.0   Complete garbage\n I tried to give this serie...
# 5  12-06-2024          1.0   I made an account just to rate this junk\n Th...
# 6  13-06-2024          1.0   Cultural Vandalism\n I have never left a one ...
# 7  05-06-2024          NaN   Garbage\n I'm a huge star wars fan and I can ...
# 8  24-06-2024          8.0   A Solid Entry in the Franchise\n The Acolyte ...
# 9  13-06-2024          1.0   The power of 1\n The power of 2, the power of...
#
#       label     score
# 0  NEGATIVE  0.994506
# 1  NEGATIVE  0.998167
# 2  NEGATIVE  0.999678
# ...

# %%
df.drop(["score"], axis=1, inplace=True)

# %%
df.rename(columns={'label': 'Sentiment'}, inplace=True)

# %%
df.head(10)
# Out:
#   Review Date  User Rating                                             Review  \
# 0  10-06-2024          3.0   Painful - how can it get this bad?\n Take one...
# 1  05-06-2024          3.0   This is laughably bad writing & direction\n W...
# 2  09-06-2024          3.0   What happened to the $180 million it cost to ...
# 3  13-06-2024          1.0   Jar Jar Binks was a museum masterpiece next t...
# 4  12-06-2024          1.0   Complete garbage\n I tried to give this serie...
# 5  12-06-2024          1.0   I made an account just to rate this junk\n Th...
# 6  13-06-2024          1.0   Cultural Vandalism\n I have never left a one ...
# 7  05-06-2024          NaN   Garbage\n I'm a huge star wars fan and I can ...
# 8  24-06-2024          8.0   A Solid Entry in the Franchise\n The Acolyte ...
# 9  13-06-2024          1.0   The power of 1\n The power of 2, the power of...
#
#   Sentiment
# 0  NEGATIVE
# 1  NEGATIVE
# 2  NEGATIVE
# 3  NEGATIVE
# 4  NEGATIVE
# 5  NEGATIVE
# 6  NEGATIVE
# ...
